# %% [markdown]
# # Stack Overflow Developer Survey Processing

# %% [markdown]
# # Content
#
# * [Configure This Notebook](#configure-this-notebook)
# * [Load Data](#load-data)
# * [Select Relevant Features](#select-relevant-features)
# * [Data Cleaning](#data-cleaning)
# * [Save Cleaned Data](#save-cleaned-data)

# %% [markdown]
# # Configure This Notebook
#
# This notebook will read in the 2024 developer survey, clean and process the data for analysis, and then save the clean version to a new location. Any configurable settings for the notebook will be set here.

# %%
# Relative file path to the 2024 developer survey results
SO_SURVEY_RAW = 'data/raw/survey_results_public.csv'

# Relative file path to store the cleaned results for future analysis
SO_SURVEY_CLEAN = 'data/clean/survey_results.csv'

# %% [markdown]
# # Load Data
#
# Every year, Stack Overflow releases the data for their annual developer survey. Our intended analysis examines the current state of the industry, and as a result, we will focus our effort on only the most recent survey from 2024.

# %%
import pandas as pd
import numpy as np

# %%
survey_results = pd.read_csv(SO_SURVEY_RAW, index_col='ResponseId')
survey_results.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Technical documentation;Blogs;Books;Written Tu...
# 3           Technical documentation;Blogs;Books;Written Tu...
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
#
#                                                       TechDoc  ...  \
# ResponseId                                                     ...
# 1                                                         NaN  ...
# 2           API document(s) and/or SDK document(s);User gu...  ...
# 3           API document(s) and/or SDK document(s);User gu...  ...
# 4                                                         NaN  ...
# 5           API document(s) and/or SDK document(s);User gu...  ...
#
#            JobSatPoints_6 JobSatPoints_7 JobSatPoints_8 JobSatPoints_9  \
# ResponseId
# 1                     NaN            NaN            NaN            NaN
# 2                     0.0            0.0            0.0            0.0
# 3                     NaN            NaN            NaN            NaN
# 4                     NaN            NaN            NaN            NaN
# 5                     NaN            NaN            NaN            NaN
#
#            JobSatPoints_10 JobSatPoints_11           SurveyLength SurveyEase  \
# ResponseId
# 1                      NaN             NaN                    NaN        NaN
# 2                      0.0             0.0                    NaN        NaN
# 3                      NaN             NaN  Appropriate in length       Easy
# 4                      NaN             NaN               Too long       Easy
# 5                      NaN             NaN              Too short       Easy
#
#            ConvertedCompYearly JobSat
# ResponseId
# 1                          NaN    NaN
# 2                          NaN    NaN
# 3                          NaN    NaN
# 4                          NaN    NaN
# 5                          NaN    NaN
#
# [5 rows x 113 columns]

# %% [markdown]
# # Select Relevant Features
#
# Our intended analysis focuses on developer skills and experience levels. As a result, we will focus on features that can directly support that analysis.

# %%
columns = ['MainBranch', 'Age', 'Employment', 'CodingActivities',
    'EdLevel', 'LearnCode', 'LearnCodeOnline', 'YearsCode', 'YearsCodePro',
    'DevType', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
    'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith',
    'WebframeHaveWorkedWith', 'WorkExp', 'Industry',
    'ConvertedCompYearly']

survey_results = survey_results[columns]
survey_results.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment  \
# ResponseId
# 1           Employed, full-time
# 2           Employed, full-time
# 3           Employed, full-time
# 4            Student, full-time
# 5            Student, full-time
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           Technical documentation;Blogs;Books;Written Tu...        20
# 3           Technical documentation;Blogs;Books;Written Tu...        37
# 4           Stack Overflow;How-to videos;Interactive tutorial         4
# 5           Technical documentation;Blogs;Written Tutorial...         9
#
#            YearsCodePro                DevType  \
# ResponseId
# 1                   NaN                    NaN
# 2                    17  Developer, full-stack
# 3                    27   Developer Experience
# 4                   NaN  Developer, full-stack
# 5                   NaN  Developer, full-stack
#
#                                                       Country Currency  \
# ResponseId
# 1                                    United States of America      NaN
# 2           United Kingdom of Great Britain and Northern I...      NaN
# 3           United Kingdom of Great Britain and Northern I...      NaN
# 4                                                      Canada      NaN
# 5                                                      Norway      NaN
#
#             CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 1                 NaN                                                NaN
# 2                 NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                 NaN                                                 C#
# 4                 NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                 NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                      DatabaseHaveWorkedWith  \
# ResponseId
# 1                                       NaN
# 2               Dynamodb;MongoDB;PostgreSQL
# 3                Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite
# 5                         PostgreSQL;SQLite
#
#                               PlatformHaveWorkedWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4            Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                NaN
#
#                             WebframeHaveWorkedWith  WorkExp Industry  \
# ResponseId
# 1                                              NaN      NaN      NaN
# 2                    Express;Next.js;Node.js;React     17.0      NaN
# 3                                     ASP.NET CORE      NaN      NaN
# 4           jQuery;Next.js;Node.js;React;WordPress      NaN      NaN
# 5                                              NaN      NaN      NaN
#
#             ConvertedCompYearly
# ResponseId
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN

# %% [markdown]
# # Data Cleaning
#
# The steps needed to clean the survey data are as follows:
# 1. Convert multi-select features into lists

# %% [markdown]
# __1. Convert multi-select features into lists__
#
# Many of the questions asked on the survey are multi-select questions, allowing one respondent to submit multiple answers for the same question. In the raw data, these are stored as a semicolon-delimited list of answers. We will convert these to list objects for easier analysis later.

# %%
expandable_columns = ['Employment', 'CodingActivities', 'LearnCode', 'LearnCodeOnline',
                      'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith',
                      'WebframeHaveWorkedWith']

for col_name in expandable_columns:
    survey_results[col_name] = survey_results[col_name].str.split(';')

survey_results.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                        Employment  \
# ResponseId
# 1           [Employed, full-time]
# 2           [Employed, full-time]
# 3           [Employed, full-time]
# 4            [Student, full-time]
# 5            [Student, full-time]
#
#                                              CodingActivities  \
# ResponseId
# 1                                                     [Hobby]
# 2           [Hobby, Contribute to open-source projects, Ot...
# 3           [Hobby, Contribute to open-source projects, Ot...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                    [Books / Physical media]
# 2           [Books / Physical media, Colleague, On the job...
# 3           [Books / Physical media, Colleague, On the job...
# 4           [Other online resources (e.g., videos, blogs, ...
# 5           [Other online resources (e.g., videos, blogs, ...
#
#                                               LearnCodeOnline YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           [Technical documentation, Blogs, Books, Writte...        20
# 3           [Technical documentation, Blogs, Books, Writte...        37
# 4           [Stack Overflow, How-to videos, Interactive tu...         4
# 5           [Technical documentation, Blogs, Written Tutor...         9
#
#            YearsCodePro                DevType  \
# ResponseId
# 1                   NaN                    NaN
# 2                    17  Developer, full-stack
# 3                    27   Developer Experience
# 4                   NaN  Developer, full-stack
# 5                   NaN  Developer, full-stack
#
#                                                       Country Currency  \
# ResponseId
# 1                                    United States of America      NaN
# 2           United Kingdom of Great Britain and Northern I...      NaN
# 3           United Kingdom of Great Britain and Northern I...      NaN
# 4                                                      Canada      NaN
# 5                                                      Norway      NaN
#
#             CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 1                 NaN                                                NaN
# 2                 NaN  [Bash/Shell (all shells), Go, HTML/CSS, Java, ...
# 3                 NaN                                               [C#]
# 4                 NaN  [C, C++, HTML/CSS, Java, JavaScript, PHP, Powe...
# 5                 NaN     [C++, HTML/CSS, JavaScript, Lua, Python, Rust]
#
#                           DatabaseHaveWorkedWith  \
# ResponseId
# 1                                            NaN
# 2                [Dynamodb, MongoDB, PostgreSQL]
# 3                   [Firebase Realtime Database]
# 4           [MongoDB, MySQL, PostgreSQL, SQLite]
# 5                           [PostgreSQL, SQLite]
#
#                                   PlatformHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2           [Amazon Web Services (AWS), Heroku, Netlify]
# 3                                         [Google Cloud]
# 4            [Amazon Web Services (AWS), Fly.io, Heroku]
# 5                                                    NaN
#
#                                   WebframeHaveWorkedWith  WorkExp Industry  \
# ResponseId
# 1                                                    NaN      NaN      NaN
# 2                     [Express, Next.js, Node.js, React]     17.0      NaN
# 3                                         [ASP.NET CORE]      NaN      NaN
# 4           [jQuery, Next.js, Node.js, React, WordPress]      NaN      NaN
# 5                                                    NaN      NaN      NaN
#
#             ConvertedCompYearly
# ResponseId
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN

# %% [markdown]
# # Save Cleaned Data
#
# Now that the data is clean, we save it to the configured directory.

# %%
survey_results.to_csv(SO_SURVEY_CLEAN)
